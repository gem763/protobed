# %%
import os
import sys
import glob
import json
import requests
import pandas as pd
import pandas_gbq as gbq
from pathlib import Path
from IPython.core.debugger import set_trace
from tqdm.auto import tqdm
tqdm.pandas()

# %%
proj = 'global-news-crawl'
table_downloaded = 'news_dataset.downloaded'
table_trashed = 'news_dataset.downloaded'

# %%
fnames = glob.glob('newsdata/downloaded/*.json')

# %%
df = {}
for fname in tqdm(fnames[:5000]):
    id = fname.split('\\')[-1].split('.')[0]
    js = json.loads(Path(fname).read_text())
    js['authors'] = ', '.join(js['authors'])
    js['nurl'] = len(js['url'])
    df[id] = js
    
df = pd.DataFrame.from_dict(df, orient='index')
df.index.name = 'id'
df = df.reset_index()

# %%
df
# Out:
#                                             id            pub  \
# 0     00016d14b570073fe5409e83925cbd80e2324a44            cnn
# 1     00021107cd7851febc6cebe32958823fa8eb3e02       atlantic
# 2     000352e92d47d523e5a7aa673f1d83b39208a7ee        reuters
# 3     00035b19217fb3d2634866d8049038c420b8d330        abcnews
# 4     00041ab21783ca33a9ea4a0a46420a01c286897b        reuters
# ...                                        ...            ...
# 4995  0632addc0ab96af37c8b1072671732a57396d6d3  investing.com
# 4996  0633b534bf2877bc6b30886723b528f0d84b6fe8            fox
# 4997  0634425fe20205bfa0c715650b2aa6378884aa06        abcnews
# 4998  06347d786521ba512880efcbb9585c55fc94901d          zdnet
# 4999  0634a87148bd90c0eac4b388de5894d1a302ec33       euronews
#
#                                                     url  \
# 0     https://us.cnn.com/2019/09/11/politics/donald-...
# 1     https://theatlantic.com/health/archive/2019/09...
# ...

# %%
gbq.to_gbq(df, table_downloaded, project_id=proj, if_exists='append', chunksize=1000)
# Out:
# 5it [00:54, 10.95s/it]
